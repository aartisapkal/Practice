# %% [markdown]
# #                                 [       PYTHON       ]

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# Python is an interpreted,interactive,Object-oriented programming language.It incorporates modules,exceptions,dynamic typing,very high level dynamic data types and classes.--------Python

# %% [markdown]
# Python is a high-level language.
#
# Pyhton is a interpreted.
#
# Pyhton is a interactive.
#
# Python is Object-Oriented.
#
# Pyhton is developed by " Guido  va  Rossum" at research institute for mathematics and computer science, Netherlands.
#
# Named after a TV show called "Monty  Python's Flying Circus" and not after Pyhton-The Snake.
#
# Van Rossum is principle author Benevolent Dictator For Life   (BDFL).
#
# Pyhton 1.0 released on January  1994.
#
# Pyhton 2.0 released on October 16,2000,with many major new features garbage collector and support for unicode.
#
# Python 3.0 released on December 3.2008.

# %% [markdown]
# # Python  " IDLE  SHELL"

# %% [markdown]
# Python IDLE stands for Integrated Development Learning Environment for Python. There are many more development environments. like  Pycharm, Eclipse, Eric etc.

# %% [markdown]
# # Jupiter

# %% [markdown]
# Jupiter extends the fonctionality of Python's interactive interpreter with a souped-up interactive shell that adds introspection, rich media , shell syntax, tab completion, and command history retrieval.

# %% [markdown]
# # Libraries   In   Pyhton     ( Pandas )

# %% [markdown]
# Python library is a collection of functions and methods that allows you to perform many actions without writing your code.

# %% [markdown]
# # What is Pandas in Python?

# %% [markdown]
# Pandas stand for Panel Data and is the core library for data manipulation and data analysis. it consist of single and multi-dimensional data-structures for data-manipulation.
#     pandas was intialy developed by "Wes Mckinney" in 2008.pandas generally provide two data structure for manipulating data are : -Series : -DataFrame.

# %% [markdown]
# # Pandas provides two data strucure for manipulating data are:-                                   Series  &  DataFrame

# %% [markdown]
# # Why Use Pandas In Python

# %% [markdown]
# Pandas is seriously a game changer when it comes to cleaning,transforming. manipulating and analyzing data.In simple termes, Pandas helps to clean the mess.
#    Pandas allows importing data from various file formats such as comma-separated values,JSON,SQL,MICROSOFT EXCEL.Pandas allows various data manipulation operations such as merging, reshaping,selecting,as well as data cleaning.

# %% [markdown]
# # Series

# %% [markdown]
# Series is a one-dimensional labeled array capable of holding data of any type any type (integer , string , float, python objects, etc.). The axis labels are collectively called index. pandas Series is nothing but a column in an excel sheet.

# %% [markdown]
# # Import Pandas as pd

# %% [markdown]
# Pandas is usually imported under the pd alias.In Python alias are an alternate name for referring to the same thing.

# %%
import pandas as pd

# %%
ser = pd.Series(data = [100,200,300,400,500], index = ['tom','bob', 'nancy', 'dan', 'eric'])

# %%
ser
# Out:
# tom      100
# bob      200
# nancy    300
# dan      400
# eric     500
# dtype: int64

# %%
ser.index
# Out:
# Index(['tom', 'bob', 'nancy', 'dan', 'eric'], dtype='object')

# %%
ser['nancy']
# Out:
# 300

# %%
ser [[4,3,1]]
# Out:
# eric    500
# dan     400
# bob     200
# dtype: int64

# %%
'bob' in ser
# Out:
# True

# %%
ser
# Out:
# tom      100
# bob      200
# nancy    300
# dan      400
# eric     500
# dtype: int64

# %%
ser*2
# Out:
# tom       200
# bob       400
# nancy     600
# dan       800
# eric     1000
# dtype: int64

# %%
ser**2
# Out:
# tom       10000
# bob       40000
# nancy     90000
# dan      160000
# eric     250000
# dtype: int64

# %% [markdown]
# ## DataFrame

# %% [markdown]
# DataFrame os two-dimensional Data Structure, that is data is aligned in a tabular fashtion in rows and columns. Pandas DataFrame consists of three principal components, the DATA , ROWS , AND  COLUMNS.

# %%
d = {'one' : pd.Series([100.,200.,300.], index = [ 'apple', 'ball', 'clock']),
    'two' : pd.Series([111.,222.,333.,4444.], index = [ 'apple', 'ball', 'cerill', 'dancy'])}

# %%
df = pd.DataFrame(d)
df
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'cerill', 'clock', 'dancy'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
pd.DataFrame(d, index=['dancy', 'ball', 'apple'])
# Out:
#          one     two
# dancy    NaN  4444.0
# ball   200.0   222.0
# apple  100.0   111.0

# %%
pd.DataFrame(d, index=['dancy', 'ball', 'apple'], columns = ['two', 'five'])
# Out:
#           two five
# dancy  4444.0  NaN
# ball    222.0  NaN
# apple   111.0  NaN

# %%
data = [ {'alex': 1, 'joe': 2},{'ema': 5, 'dora': 10, 'alice': 20} ]

# %%
pd.DataFrame(data)
# Out:
#    alex  joe  ema  dora  alice
# 0   1.0  2.0  NaN   NaN    NaN
# 1   NaN  NaN  5.0  10.0   20.0

# %%
pd.DataFrame(data, index = [ 'orange', 'red'])
# Out:
#         alex  joe  ema  dora  alice
# orange   1.0  2.0  NaN   NaN    NaN
# red      NaN  NaN  5.0  10.0   20.0

# %%
pd.DataFrame(data, columns = [ 'joe', 'dora', 'alice'])
# Out:
#    joe  dora  alice
# 0  2.0   NaN    NaN
# 1  NaN  10.0   20.0

# %%
df
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df['one']
# Out:
# apple     100.0
# ball      200.0
# cerill      NaN
# clock     300.0
# dancy       NaN
# Name: one, dtype: float64

# %%
df['three']=  df['one']*df['two']
df
# Out:
#           one     two    three
# apple   100.0   111.0  11100.0
# ball    200.0   222.0  44400.0
# cerill    NaN   333.0      NaN
# clock   300.0     NaN      NaN
# dancy     NaN  4444.0      NaN

# %%
df['flag']=  df['one']>250
df
# Out:
#           one     two    three   flag
# apple   100.0   111.0  11100.0  False
# ball    200.0   222.0  44400.0  False
# cerill    NaN   333.0      NaN  False
# clock   300.0     NaN      NaN   True
# dancy     NaN  4444.0      NaN  False

# %%
three = df.pop('three')
df
# Out:
#           one     two   flag
# apple   100.0   111.0  False
# ball    200.0   222.0  False
# cerill    NaN   333.0  False
# clock   300.0     NaN   True
# dancy     NaN  4444.0  False

# %%
three
# Out:
# apple     11100.0
# ball      44400.0
# cerill        NaN
# clock         NaN
# dancy         NaN
# Name: three, dtype: float64

# %%
del df ['two']
df
# Out:
#           one   flag
# apple   100.0  False
# ball    200.0  False
# cerill    NaN  False
# clock   300.0   True
# dancy     NaN  False

# %%
df.insert(0, 'copy of one' ,df ['one'])
df
# Out:
#         copy of one    one   flag
# apple         100.0  100.0  False
# ball          200.0  200.0  False
# cerill          NaN    NaN  False
# clock         300.0  300.0   True
# dancy           NaN    NaN  False

# %%
df['one_upper_half'] = df['one'][:2]
df
# Out:
#         copy of one    one   flag  one_upper_half
# apple         100.0  100.0  False           100.0
# ball          200.0  200.0  False           200.0
# cerill          NaN    NaN  False             NaN
# clock         300.0  300.0   True             NaN
# dancy           NaN    NaN  False             NaN

# %% [markdown]
# # PD Read CSV

# %% [markdown]
# read_csv  is an important pandas function to read csv files and do operations on it.
#
# A CSV file is a type of plain text file that uses specific structuring to arrange tabular data. because its a plain text file, it can contain only actual text data.

# %%
import pandas as pd

# %%
movies = pd.read_csv(r'C:\Users\aarti\OneDrive\Desktop\data set\movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.tail()
# Out:
#        movieId                           title                  genres
# 62418   209157                       We (2018)                   Drama
# 62419   209159       Window of the Soul (2001)             Documentary
# 62420   209163                Bad Poems (2018)            Comedy|Drama
# 62421   209169             A Girl Thing (2001)      (no genres listed)
# 62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama

# %%
tags = pd.read_csv(r'C:\Users\aarti\OneDrive\Desktop\data set\tags.csv')
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
ratings = pd.read_csv(r'C:\Users\aarti\OneDrive\Desktop\data set\ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
del ratings['timestamp']
del tags['timestamp']

# %% [markdown]
# # Data Structure

# %% [markdown]
# ## Series

# %%
tags.head()
# Out:
#    userId  movieId               tag
# 0       3      260           classic
# 1       3      260            sci-fi
# 2       4     1732       dark comedy
# 3       4     1732    great dialogue
# 4       4     7569  so bad it's good

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=1093360, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,2000]]
# Out:
#       userId  movieId           tag
# 0          3      260       classic
# 11         4   164909        cliche
# 2000     647   164179  twist ending

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# A large number of methods collectively compute descriptive statistics and other related operations on DataFrame.
#
# The describe() function conputes a summary of statistics pertaining to the DataFrame columns.

# %%
ratings['rating'].describe()
# Out:
# count    2.500010e+07
# mean     3.533854e+00
# std      1.060744e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings['rating'].mean()
# Out:
# 3.533854451353085

# %%
ratings.mean()
# Out:
# userId     81189.281154
# movieId    21387.981943
# rating         3.533854
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.0607439610179747

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.004413  0.001940
# movieId -0.004413  1.000000 -0.009216
# rating   0.001940 -0.009216  1.000000

# %%
filter_1 = ratings['rating']>5
filter_1.any()
# Out:
# False

# %%
filter_1.all()
# Out:
# False

# %%
filter_2 = ratings['rating']>0
filter_2.any()
# Out:
# True

# %%
filter_2.all()
# Out:
# True

# %%
movies.shape
# Out:
# (62423, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.shape
# Out:
# (25000095, 3)

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags=tags.dropna()

# %%
tags.shape
# Out:
# (1093344, 3)

# %% [markdown]
# # Graph

# %% [markdown]
# # MATPLOTLIB

# %% [markdown]
# Matplotlib is a Python library used for data visualization.
# we can create bar-plots, scatter-plots, histograms and a lot more with matplotlib.
#
# matplotlib is the standard Python library for creating 2D plots and graphs.

# %%
# %matplotlib inline
ratings.hist(column = 'rating', figsize = (5,5))
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>]], dtype=object)

# %% [markdown]
# # Slicing

# %% [markdown]
# Slicing using the [] op
# erator selects a set of rows and culumns from a DataFrame.

# %%
tags['tag'].head()
# Out:
# 0             classic
# 1              sci-fi
# 2         dark comedy
# 3      great dialogue
# 4    so bad it's good
# Name: tag, dtype: object

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[1000:1010]
# Out:
#       userId  movieId  rating
# 1000       4    45517     2.5
# 1001       4    45722     3.5
# 1002       4    46948     2.5
# 1003       4    46972     3.5
# 1004       4    48780     5.0
# 1005       4    48982     3.0
# 1006       4    49272     3.5
# 1007       4    49396     3.5
# 1008       4    49649     1.0
# 1009       4    50601     1.5

# %%
tags_counts=tags['tag'].value_counts()
tags_counts[:10]
# Out:
# sci-fi                8330
# atmospheric           6516
# action                5907
# comedy                5702
# surreal               5326
# based on a book       5079
# twist ending          4820
# funny                 4738
# visually appealing    4526
# dystopia              4257
# Name: tag, dtype: int64

# %%
tags_counts[:10].plot(kind='bar', figsize=(5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Filter

# %% [markdown]
# Filter() function is used to Subset rows or columns of dataframe according to lables in the specified index. The filter is applied to the labels of the index.

# %%
is_highly_rated = ratings['rating'] >= 4.0
ratings[is_highly_rated][-5:]
ratings[is_highly_rated].tail()
# Out:
#           userId  movieId  rating
# 25000088  162541    41566     4.0
# 25000089  162541    45517     4.5
# 25000090  162541    50872     4.5
# 25000093  162541    58559     4.0
# 25000094  162541    63876     5.0

# %%
is_animation = movies['genres'].str.contains('Animation')
movies[is_animation][5:15]
# Out:
#      movieId                                       title  \
# 309      313                   Swan Princess, The (1994)
# 359      364                       Lion King, The (1994)
# 387      392  Secret Adventures of Tom Thumb, The (1993)
# 545      551      Nightmare Before Christmas, The (1993)
# 551      558                      Pagemaster, The (1994)
# 580      588                              Aladdin (1992)
# 586      594      Snow White and the Seven Dwarfs (1937)
# 587      595                 Beauty and the Beast (1991)
# 588      596                            Pinocchio (1940)
# 602      610                          Heavy Metal (1981)
#
#                                               genres
# 309                               Animation|Children
# 359  Adventure|Animation|Children|Drama|Musical|IMAX
# 387                              Adventure|Animation
# 545               Animation|Children|Fantasy|Musical
# 551      Action|Adventure|Animation|Children|Fantasy
# ...

# %%
movies[is_animation].head(15)
# Out:
#      movieId                                       title  \
# 0          1                            Toy Story (1995)
# 12        13                                Balto (1995)
# 47        48                           Pocahontas (1995)
# 236      239                       Goofy Movie, A (1995)
# 241      244                     Gumby: The Movie (1995)
# 309      313                   Swan Princess, The (1994)
# 359      364                       Lion King, The (1994)
# 387      392  Secret Adventures of Tom Thumb, The (1993)
# 545      551      Nightmare Before Christmas, The (1993)
# 551      558                      Pagemaster, The (1994)
# 580      588                              Aladdin (1992)
# 586      594      Snow White and the Seven Dwarfs (1937)
# 587      595                 Beauty and the Beast (1991)
# 588      596                            Pinocchio (1940)
# 602      610                          Heavy Metal (1981)
#
# ...

# %% [markdown]
# # Groupby

# %% [markdown]
# Groupby () function is used to split the data into groups based on some criteria. pandas objects can split on any of their axes.

# %%
ratings_count = ratings[['movieId', 'rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      393068
# 1.0      776815
# 1.5      399490
# 2.0     1640868
# 2.5     1262797
# 3.0     4896928
# 3.5     3177318
# 4.0     6639798
# 4.5     2200539
# 5.0     3612474

# %%
average_count = ratings[['movieId', 'rating']].groupby('movieId').mean()
average_count.head()
# Out:
#            rating
# movieId
# 1        3.893708
# 2        3.251527
# 3        3.142028
# 4        2.853547
# 5        3.058434

# %%
movie_count = ratings[['movieId', 'rating']].groupby('movieId').count()
movie_count.head()
# Out:
#          rating
# movieId
# 1         57309
# 2         24228
# 3         11804
# 4          2523
# 5         11714

# %%
movie_count.tail()
# Out:
#          rating
# movieId
# 209157        1
# 209159        1
# 209163        1
# 209169        1
# 209171        1

# %% [markdown]
# # Merge

# %%
tags.head()
# Out:
#    userId  movieId               tag
# 0       3      260           classic
# 1       3      260            sci-fi
# 2       4     1732       dark comedy
# 3       4     1732    great dialogue
# 4       4     7569  so bad it's good

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags, on = 'movieId', how = 'inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId           tag
# 0     791         Owned
# 1    1048  imdb top 250
# 2    1361         Pixar
# 3    3164         Pixar
# 4    3164   time travel

# %%
f = movies.merge(tags, on = 'movieId', how = 'outer')
f.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId           tag
# 0   791.0         Owned
# 1  1048.0  imdb top 250
# 2  1361.0         Pixar
# 3  3164.0         Pixar
# 4  3164.0   time travel

# %%
print("\U0001F923")
# Out:
# 🤣

# %%
avg_ratings = ratings.groupby('movieId', as_index = False).mean()
del avg_ratings['userId']
ratings_count
# Out:
#         movieId
# rating
# 0.5      393068
# 1.0      776815
# 1.5      399490
# 2.0     1640868
# 2.5     1262797
# 3.0     4896928
# 3.5     3177318
# 4.0     6639798
# 4.5     2200539
# 5.0     3612474

# %%
box_office = movies.merge(avg_ratings, on = 'movieId', how = 'inner')
box_office.tail()
# Out:
#        movieId                           title                  genres  rating
# 59042   209157                       We (2018)                   Drama     1.5
# 59043   209159       Window of the Soul (2001)             Documentary     3.0
# 59044   209163                Bad Poems (2018)            Comedy|Drama     4.5
# 59045   209169             A Girl Thing (2001)      (no genres listed)     3.0
# 59046   209171  Women of Devil's Island (1962)  Action|Adventure|Drama     3.0

# %%
is_highly_rated = box_office['rating'] >= 4.0
box_office[is_highly_rated][-5:]
# Out:
#        movieId                                              title  \
# 59027   209121        Adrenalin: The BMW Touring Car Story (2014)
# 59028   209123  Square Roots: The Story of SpongeBob SquarePan...
# 59029   209129                           Destination Titan (2011)
# 59041   209155                         Santosh Subramaniam (2008)
# 59044   209163                                   Bad Poems (2018)
#
#                       genres  rating
# 59027            Documentary     4.0
# 59028            Documentary     4.0
# 59029            Documentary     4.5
# 59041  Action|Comedy|Romance     5.0
# 59044           Comedy|Drama     4.5

# %%
is_comedy = box_office['genres'].str.contains('Comedy')
box_office[is_comedy][-5:]
# Out:
#        movieId                                     title  \
# 59026   209119                    Up to the World (2014)
# 59035   209141  And They Lived Happily Ever After (1976)
# 59040   209153                       Happy Flight (2008)
# 59041   209155                Santosh Subramaniam (2008)
# 59044   209163                          Bad Poems (2018)
#
#                       genres  rating
# 59026           Comedy|Drama     3.5
# 59035                 Comedy     1.0
# 59040           Comedy|Drama     2.5
# 59041  Action|Comedy|Romance     5.0
# 59044           Comedy|Drama     4.5

# %%
box_office[is_comedy & is_highly_rated][-5:]
# Out:
#        movieId                       title  \
# 58990   208911   Cheating in Chains (2006)
# 58998   208939                Klaus (2019)
# 59001   208945               Powder (2019)
# 59041   209155  Santosh Subramaniam (2008)
# 59044   209163            Bad Poems (2018)
#
#                                     genres  rating
# 58990                               Comedy  4.0000
# 58998  Adventure|Animation|Children|Comedy  4.3125
# 59001                         Comedy|Drama  4.5000
# 59041                Action|Comedy|Romance  5.0000
# 59044                         Comedy|Drama  4.5000

# %% [markdown]
# # Vectorized String Operations

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies_genres = movies['genres'].str.split('|', expand=True)
movies_genres[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None

# %%
movies_genres['isComedy'] = movies['genres'].str.contains('Comedy')
movies_genres[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9  isComedy
# 0  None      True
# 1  None     False
# 2  None      True
# 3  None      True
# 4  None      True
# 5  None     False
# ...

# %%
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %% [markdown]
# # Time

# %%
tags = pd.read_csv(r'C:\Users\aarti\OneDrive\Desktop\data set\tags.csv')
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags['parsed_time'] = pd.to_datetime(tags['timestamp'], unit = 's')
tags.head()
# Out:
#    userId  movieId               tag   timestamp         parsed_time
# 0       3      260           classic  1439472355 2015-08-13 13:25:55
# 1       3      260            sci-fi  1439472256 2015-08-13 13:24:16
# 2       4     1732       dark comedy  1573943598 2019-11-16 22:33:18
# 3       4     1732    great dialogue  1573943604 2019-11-16 22:33:24
# 4       4     7569  so bad it's good  1573943455 2019-11-16 22:30:55

# %%
tags['parsed_time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
greater_than_t = tags['parsed_time'] > '2015-02-01'
selected_rows = tags[greater_than_t]
tags.shape, selected_rows.shape
# Out:
# ((1093360, 5), (692112, 5))

# %%
tags.sort_values(by = 'parsed_time', ascending=True)[:10]
# Out:
#         userId  movieId              tag   timestamp         parsed_time
# 900600  129396     2788     monty python  1135429210 2005-12-24 13:00:10
# 900595  129396     1732    coen brothers  1135429236 2005-12-24 13:00:36
# 900592  129396     1206  stanley kubrick  1135429248 2005-12-24 13:00:48
# 900591  129396     1193   jack nicholson  1135429371 2005-12-24 13:02:51
# 900607  129396     5004    peter sellers  1135429399 2005-12-24 13:03:19
# 900589  129396       47        brad pitt  1135429412 2005-12-24 13:03:32
# 900590  129396       47   morgan freeman  1135429412 2005-12-24 13:03:32
# 900605  129396     4011      guy ritchie  1135429431 2005-12-24 13:03:51
# 900604  129396     4011        brad pitt  1135429431 2005-12-24 13:03:51
# 900588  129396       32     bruce willis  1135429442 2005-12-24 13:04:02

# %% [markdown]
# # Average Movie Ratings Over Time

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1      296     5.0
# 1       1      306     3.5
# 2       1      307     5.0
# 3       1      665     5.0
# 4       1      899     3.5

# %%
average_rating = ratings[['movieId', 'rating']].groupby('movieId', as_index = False).mean()
average_rating.tail()
# Out:
#        movieId  rating
# 59042   209157     1.5
# 59043   209159     3.0
# 59044   209163     4.5
# 59045   209169     3.0
# 59046   209171     3.0

# %%
joined = movies.merge(average_rating, on='movieId', how = 'inner')
joined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995  3.893708
# 1                   Adventure|Children|Fantasy  1995  3.251527
# 2                               Comedy|Romance  1995  3.142028
# 3                         Comedy|Drama|Romance  1995  2.853547
# 4                                       Comedy  1995  3.058434

# %%
joined.corr()
# Out:
#           movieId    rating
# movieId  1.000000 -0.093459
# rating  -0.093459  1.000000

# %%
yearly_average = joined[['year', 'rating']].groupby('year', as_index = False).mean()
yearly_average[:10]
# Out:
#    year    rating
# 0  1874  3.027778
# 1  1878  2.909091
# 2  1880  2.666667
# 3  1883  2.636364
# 4  1887  1.750000
# 5  1888  2.373042
# 6  1890  2.196667
# 7  1891  1.692842
# 8  1892  1.530769
# 9  1894  2.376825

# %%
yearly_average[-5:]
# Out:
#                      year    rating
# 135                  2018  3.014278
# 136                  2019  2.652123
# 137       Close Relations  4.250000
# 138    Das Millionenspiel  3.400000
# 139  Your Past Is Showing  3.083333

# %%
yearly_average[-20:].plot(x = 'year', y = 'rating', figsize = (5,5), grid = True)
# Out:
# <AxesSubplot:xlabel='year'>
